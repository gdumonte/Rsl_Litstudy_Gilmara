# %%
# By Gilmara Santos
# This notebook shows how to use litstudy from inside a Jupyter notebook. It shows how to load a dataset, 
#plot statistics, perform topic modeling, do network analysis, and other features.

# This notebook focuses on doing a systematic literature review with topics on research that use Fog Computing solutions 
#for Sustainable IoT data management

# Import other libraries 
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import matplotlib.colors as mcolors
import seaborn as sbs

# Options for plots
plt.rcParams['figure.figsize'] = (10, 6)
sbs.set('paper')
#plt.style.use('fast')

# Import litstudy
path = os.path.abspath(os.path.join('..'))
if path not in sys.path:
    sys.path.append(path)

import litstudy

# %%
# For the scope of this research, the CAPES journal portal was adopted as a data source, 
#therefore, the research will take place in the following digital libraries: IEEE Xplore, Springer Link, 
#Web of Science - Coleção Principal (Clarivate Analytics).

# Load the CSV files
docs1 = litstudy.load_ieee_csv('data/export_IEEE.csv')
docs_ieee = docs1
print(len(docs_ieee), 'papers loaded from IEEE')

docs_springer = litstudy.load_springer_csv('data/SpringerLink.csv')
print(len(docs_springer), 'papers loaded from Springer')

doc_web_of_science = litstudy.load_bibtex('data/webOfScience.bib')
print(len(doc_web_of_science), 'papers loaded from Bibtex')

# Merge the three document sets (This option already removes duplicate articlesv - For more information
#see the DocumentSet class and its methods (union, intersection, merge) in the types file)
docs_csv = docs_ieee | docs_springer | doc_web_of_science
print(len(docs_csv), 'papers loaded from CSV')
# Out:
# 51 papers loaded from IEEE
# 66 papers loaded from Springer
# 63 papers loaded from Bibtex
# 167 papers loaded from CSV

# %%
#To enhance the metadata, we can find the corresponding articles on Scopus using refine_scopus
import logging
logging.getLogger().setLevel(logging.CRITICAL)
#logging.getLogger().setLevel(logging.INFO)
logging.disable(logging.CRITICAL)
logging.disable(logging.WARNING)
logging.disable(logging.INFO)
logging.disable(logging.DEBUG)

# Refine using Scopus
docs_scopus, docs_notfound = litstudy.refine_scopus(docs_csv)
# print(len(docs_scopus), " found on Scopus, " , len(docs_notfound), " not found " )

print(len(docs_scopus), 'papers found on Scopus')
print(len(docs_notfound), 'papers were not found and were discarded')
# Out:
#  25%|████████████████████▎                                                            | 42/167 [00:00<00:02, 54.33it/s]D:\Liststudy\jupyterListstudy\lib\site-packages\litstudy\sources\scopus.py:230: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(f"no document found for DOI {doi}: {e}")
# 100%|████████████████████████████████████████████████████████████████████████████████| 167/167 [00:03<00:00, 46.37it/s]
# 162 papers found on Scopus
# 5 papers were not found and were discarded

# %%
docs = docs_scopus.filter_docs(lambda d: d.publication_year >= 2019)

# %%
litstudy.plot_year_histogram(docs_csv);

# %%
df = pd.DataFrame(docs)
#csv_data_gilmara = df.to_csv(sep='|')
print('\nCSV String:\n', df)

df.to_csv('gilmara.csv', sep='|')
#dt.to_csv('csv_data_gilmara.csv')
# Out:
# CSV String:
#  |0
# 0|<KFIML: Kubernetes-Based Fog Computing IoT Platform for Online Machine Learning>
# 1|<Auction mechanisms in cloud/fog computing resource allocation for public blockchain networks>
# 2|<A Novel Framework for Fog Computing: Lattice-Based Secured Framework for Cloud Interface>
# 3|<Privacy-Preserving Deduplication of Sensor Compressed Data in Distributed Fog Computing>
# 4|<Privacy-Preserving Traffic Monitoring with False Report Filtering via Fog-Assisted Vehicular Crowdsensing>
# 5|<A Secure Data Sharing Based on Key Aggregate Searchable Encryption in Fog-Enabled IoT Environment>
# 6|<A Fog-Based Architecture for Latency-Sensitive Monitoring Applications in Industrial Internet of Things>
# 7|<A Fog-Based Recommender System>
# 8|<A New Layered Architecture for Future Big Data-Driven Smart Homes>
# 9|<Secure identifier management based on blockchain technology in NDN environment>
# 10|<Secure fog-assisted crowdsensing with collusion resistance: From data reporting to data requesting>
# 11|<Edge Computing Technology Enablers: A Systematic Lecture Study>
# 12|<Guest Editorial Enabling Technologies for Next Generation Telehealthcare>
# 13|<Cost-performance trade-offs in fog computing for iot data processing of social virtual reality>
# 14|<IoT data processing in the fog: Functions, streams, or batch processing?>
# 15|<Secure Distributed Data Management for Fog Computing in Large-Scale IoT Application: A Blockchain-Based Solution>
# 16|<A Review On Relationship Between Iot- Cloud Computing - Fog Computing (Applications And Challenges)>
# 17|<Data Management Portfolio for Improvement of Privacy in Fog-to-cloud Computing Systems>
# 18|<Data aggregation challenges in fog computing>
# 19|<A Robust Security Framework based on Blockchain and SDN for Fog Computing enabled Agricultural Internet of Things>
# 20|<FOG Computing for Vineyard Applications>
# 21|<Heterogeneous Fog Computing Implementation for Internet of Things Applications>
# 22|<Enhancing Privacy and Security in Crowds using Fog Computing>
# 23|<Fog function: Serverless fog computing for data intensive IoT services>
# 24|<A multi-Agent based model for task scheduling in cloud-fog computing platform>
# 25|<From cloud computing to fog computing: Two technologies to serve iot-a review->
# 26|<An Intelligent Decision Support Model for Emergency Management in the Fog Computing Environment>
# 27|<A Survey on Data Integrity Checking and Enhancing Security for Cloud to Fog Computing>
# 28|<A Nearest Neighbors based Data Filter for Fog Computing in IoT Smart Agriculture>
# 29|<Design of Smart Dashboard based on IoT Fog Computing for Smart Cities>
# 30|<A Framework of IOT Service Assignment To Mitigate The Service Latency With Collaboration Of Fog and Cloud>
# 31|<Remote health monitoring system of elderly based on Fog to Cloud (F2C) computing>
# 32|<A Cost-Aware Resource Management Technique for Cloud and Edge Environment>
# 33|<Reducing IoT Bandwidth Requirements by Fog-Based Distributed Hash Tables>
# 34|<A review of IoT architectures in smart healthcare applications>
# 35|<Maintaining data integrity in fog computing based critical infrastructure systems>
# 36|<Preserving Data Management Security through Fog to Cloud Computing>
# 37|<A smart fog-To-cloud system in airport: Challenges and lessons learnt>
# 38|<F2MC: Enhancing Data Storage Services with Fog-toMultiCloud Hybrid Computing>
# 39|<Towards Predictive Replica Placement for Distributed Data Stores in Fog Environments>
# 40|<Multi-layer stream orchestration with flange>
# 41|<Fog-Enabled Industrial WSNs to Monitor Asynchronous Electric Motors>
# 42|<Secure Management of Healthcare Data in Fog and IoT Networks: A Short Survey on Existing Security Protocols>
# 43|<Legal Considerations of IoT Applications in Fog and Cloud Environments>
# 44|<A survey on IOT enabled cloud platforms>
# 45|<Security Embedded Offloading Requirements for IoT-Fog Paradigm>
# 46|<Federated Learning toward Data Preprocessing: COVID-19 Context>
# 47|<Authentication of IoT in Smart City Applications>
# 48|<DeepMist: Toward Deep Learning Assisted Mist Computing Framework for Managing Healthcare Big Data>
# 49|<Location-aware Task Allocation Strategies for IoT-Fog-Cloud Environments>
# 50|<An ECC-based lightweight remote user authentication and key management scheme for IoT communication in context of fog computing>
# 51|<Edge Computing Based Applications in Vehicular Environments: Comparative Study and Main Issues>
# 52|<Edge computing: current trends, research challenges and future directions>
# 53|<Analytic Study of Containerizing Stateful Stream Processing as Microservice to Support Digital Twins in Fog Computing>
# 54|<Reliable federated learning in a cloud-fog-IoT environment>
# 55|<A systematic study of load balancing approaches in the fog computing environment>
# 56|<Distributed Data Platform for Machine Learning Using the Fog Computing Model>
# 57|<Notions of architecture in fog computing>
# 58|<A genetic-based approach for service placement in fog computing>
# 59|<Fog computing: from architecture to edge computing and big data processing>
# 60|<An efficient framework for trust evaluation of secure service selection in fog computing based on QoS, reputation, and social criteria>
# 61|<Situational data protection in fog computing Situativer Datenschutz im Fog-Computing>
# 62|<A queuing theory model for fog computing>
# 63|<An analytical modelling and QoS evaluation of fault-tolerant load balancer and web servers in fog computing>
# 64|<Transitions for Increased Flexibility in Fog Computing: A Case Study on Complex Event Processing>
# 65|<A systematic survey of data mining and big data analysis in internet of things>
# 66|<Containerized deployment of micro-services in fog devices: a reinforcement learning-based approach>
# 67|<Classification of resource management approaches in fog/edge paradigm and future research prospects: a systematic review>
# 68|<Blockchain-based solutions for security, privacy, and trust management in vehicular networks: a survey>
# 69|<An efficient gray system theory-based routing protocol for energy consumption management in the Internet of Things using fog and cloud computing>
# 70|<Software-Defined Dew, Roof, Fog and Cloud (SD-DRFC) Framework for IoT Ecosystem: The Journey, Novel Framework Architecture, Simulation, and Use Cases>
# 71|<Dynamic urban evaluation routing protocol for enhanced vehicle ad hoc networks>
# 72|<HBI-LB: A Dependable Fault-Tolerant Load Balancing Approach for Fog based Internet-of-Things Environment>
# 73|<Fog-based architecture for scheduling multiple workflows with high availability requirement>
# 74|<Towards sustainable smart IoT applications architectural elements and design: opportunities, challenges, and open directions>
# 75|<A verifiable privacy-preserving data collection scheme supporting multi-party computation in fog-based smart grid>
# 76|<A novel IoT–fog–cloud-based healthcare system for monitoring and predicting COVID-19 outspread>
# 77|<Fog-Cloud-IoT centric collaborative framework for machine learning-based situation-aware traffic management in urban spaces>
# 78|<Cyber-physical systems for structural health monitoring: sensing technologies and intelligent computing>
# 79|<Research on a Communication Platform Coordinating Web Services and Smart Speakers on the Application Layer>
# 80|<Emergent models, frameworks, and hardware technologies for Big data analytics>
# 81|<MAA: multi-objective artificial algae algorithm for workflow scheduling in heterogeneous fog-cloud environment>
# 82|<Multi-modal secure healthcare data dissemination framework using blockchain in IoMT>
# 83|<Containerization technologies: taxonomies, applications and challenges>
# 84|<A Reference Architecture for IoT-Enabled Smart Buildings>
# 85|<Classical and quantum compression for edge computing: the ubiquitous data dimensionality reduction>
# 86|<A mobile edge computing-based applications execution framework for Internet of Vehicles>
# 87|<Enabling distributed intelligence for the Internet of Things with IOTA and mobile agents>
# 88|<Composition of caching and classification in edge computing based on quality optimization for SDN-based IoT healthcare solutions>
# 89|<TFAS: two factor authentication scheme for blockchain enabled IoMT using PUF and fuzzy extractor>
# 90|<An overview of data reduction solutions at the edge of IoT systems: a systematic mapping of the literature>
# 91|<Highly efficient key agreement for remote patient monitoring in MEC-enabled 5G networks>
# 92|<Privacy and security federated reference architecture for Internet of Things 物联网隐私与安全联合参考架构>
# 93|<Edge computing: A grounded theory study>
# 94|<Internet of Things (IoT) in Pharmaceutical Manufacturing, Warehousing, and Supply Chain Management>
# 95|<Edge-based personal computing services: fall detection as a pilot study>
# 96|<Quality and Security Frameworks for IoT-Architecture Models Evaluation>
# 97|<Digital Twins, Internet of Things and Mobile Medicine: A Review of Current Platforms to Support Smart Healthcare>
# 98|<A distributed task orchestration scheme in collaborative vehicular cloud edge networks>
# 99|<Performance analysis of the ubiquitous and emergent properties of an autonomic reflective middleware for smart cities>
# 100|<Bio-inspired Computing Techniques for Data Security Challenges and Controls>
# 101|<Internet of Things in Animal Healthcare (IoTAH): Review of Recent Advancements in Architecture, Sensing Technologies and Real-Time Monitoring>
# 102|<Internet of Low-Altitude UAVs (IoLoUA): a methodical modeling on integration of Internet of “Things” with “UAV” possibilities and tests>
# 103|<A multi-agent architecture for scheduling in platform-based smart manufacturing systems>
# 104|<A Survey on Security and Privacy Issues in Contact Tracing Application of Covid-19>
# 105|<IoT-enabled healthcare systems using block chain-dependent adaptable services>
# 106|<Protection of data privacy from vulnerability using two-fish technique with Apriori algorithm in data mining>
# 107|<The utilization of algorithms for cloud internet of things application domains: a review>
# 108|<SEOT: Secure dynamic searchable encryption with outsourced ownership transfer>
# 109|<An intelligent internet of things-based secure healthcare framework using blockchain technology with an optimal deep learning model>
# 110|<Micro-batch and data frequency for stream processing on multi-cores>
# 111|<Towards big services: a synergy between service computing and parallel programming>
# 112|<ModChain: a hybridized secure and scaling blockchain framework for IoT environment>
# 113|<Secure Authentication Framework for SDN-IoT network using Keccak-256 and Bliss-B algorithms>
# 114|<A Systematic Review on Software Architectures for IoT Systems and Future Direction to the Adoption of Microservices Architecture>
# 115|<Design principles, architectural smells and refactorings for microservices: a multivocal review>
# 116|<A fault tolerant data management scheme for healthcare internet of things in fog computing>
# 117|<A Deployment Model for IoT Devices Based on Fog Computing for Data Management and Analysis>
# 118|<Data replica placement approaches in fog computing: a review>
# 119|<Dependability in fog computing: Challenges and solutions>
# 120|<Subjective logic-based trust model for fog computing>
# 121|<Fog computing in health: A systematic literature review>
# 122|<Fog computing for smart cities’ big data management and analytics: A review>
# 123|<Genetic-based optimization in fog computing: Current trends and research opportunities>
# 124|<A replication and migration strategy on the hierarchical architecture in the fog computing environment>
# 125|<Fuzzy-assisted machine learning framework for the fog-computing system in remote healthcare monitoring>
# 126|<Fog data management: A vision, challenges, and future directions>
# 127|<Fog computing and Internet of Things in one building block: a survey and an overview of interacting technologies>
# 128|<Improving Health Monitoring With Adaptive Data Movement in Fog Computing>
# 129|<Energy-efficient fog computing in Internet of Things based on Routing Protocol for Low-Power and Lossy Network with Contiki>
# 130|<An efficient data replica placement mechanism using biogeography-based optimization technique in the fog computing environment>
# 131|<A fog computing-based device-driven mobility management scheme for 5G networks>
# 132|<The fog computing/edge computing to leverage Digital Twin>
# 133|<Fuzzy allocation model for health care data management on IoT assisted wearable sensor platform>
# 134|<Internet of Things data management: A systematic literature review, vision, and future trends>
# 135|<From zero to fog: Efficient engineering of fog-based Internet of Things applications>
# 136|<FoT-Stream: A Fog platform for data stream analytics in IoT>
# 137|<Fog-Based Data Distribution Service (F-DAD) for Internet of Things (IoT) applications>
# 138|<An Innovative Cloud-Fog-Based Smart Grid Scheme for Efficient Resource Utilization>
# 139|<Analysis of quality of service metrics and the security concerns in integrated cloud-fog environment for healthcare system>
# 140|<A drone-based data management and optimization using metaheuristic algorithms and blockchain smart contracts in a secure fog environment>
# 141|<A multi-agent-based data collection and aggregation model for fog-enabled cloud monitoring>
# 142|<Serverless data pipeline approaches for IoT data in fog and cloud computing>
# 143|<Research on fog resource scheduling based on cloud-fog collaboration technology in the electric internet of things>
# 144|<Code-based encryption techniques with distributed cluster head and energy consumption routing protocol>
# 145|<An efficient data-balancing cyber-physical system paradigm for quality-of-service (QoS) provision over fog computing>
# 146|<Content-centric data and computation offloading in AI-supported fog networks for next generation IoT>
# 147|<mySense: A comprehensive data management environment to improve precision agriculture practices>
# 148|<PF-BTS: A Privacy-Aware Fog-enhanced Blockchain-assisted task scheduling>
# 149|<Cloud and distributed architectures for data management in agriculture 4.0: Review and future trends>
# 150|<A re-organizing biosurveillance framework based on fog and mobile edge computing>
# 151|<A comprehensive study on managing strategies in the fog environments>
# 152|<A scalable IoT-fog framework for urban sound sensing>
# 153|<A manifesto for future generation cloud computing: Research directions for the next decade>
# 154|<Drone services: issues in drones for location-based services from human-drone interaction to information processing>
# 155|<Information processing in Internet of Things using big data analytics>
# 156|<iBlock: An Intelligent Decentralised Blockchain-based Pandemic Detection and Assisting System>
# 157|<Stackelberg game for service deployment of iot-enabled applications in 6g-aware fog networks>
# 158|<A comprehensive survey on software-defined networking for smart communities>
# 159|<IoT registration and authentication in smart city applications with blockchain>
# 160|<Edge-Computing-Enabled Smart Cities: A Comprehensive Survey>
# 161|<An empirical study on system level aspects of Internet of Things (IoT)>

# %%
print(len(docs), 'papers remaining')
# Out:
# 162 papers remaining

# %%
litstudy.plot_author_histogram(docs)
# Out:
# <Axes: title={'center': 'Authors'}, xlabel='No. of documents'>

# %%
# This names are long, which is why a short abbreviation is provided.
mapping = {
    "IEEE International parallel and distributed processing symposium IPDPS": "IEEE IPDPS",
    "IEEE International parallel and distributed processing symposium workshops IPDPSW": "IEEE IPDPS Workshops",
}
litstudy.plot_affiliation_histogram(docs, limit =15)
# Out:
# <Axes: title={'center': 'Affiliations'}, xlabel='No. of documents'>

# %%
litstudy.plot_country_histogram(docs)
# Out:
# <Axes: title={'center': 'Countries'}, xlabel='No. of documents'>

# %%
litstudy.plot_continent_histogram(docs);

# %%
corpus = litstudy.build_corpus(docs , ngram_threshold=0.6)

# %%
 litstudy.plot_word_distribution(corpus, limit=30) #Fig. 3
# Out:
# <Axes: xlabel='% of documents'>

# %%
#corpus = litstudy.build_corpus(docs, ngram_threshold=0.8)
corpus = litstudy.build_corpus(docs, ngram_threshold=0.8)

# %%
litstudy.compute_word_distribution(corpus).filter(like='_', axis=0).sort_index()
# Out:
#                          count
# artificial_intelligence      6
# author_exclusive            41
# business_media              22
# defined_networking           6
# energy_consumption          20
# fault_tolerant               6
# gmbh_austria                10
# internet_things             77
# john_wiley                   5
# licence_science             22
# llc_nature                  22
# load_balancing               7
# machine_learning             8
# media_llc                    6
# science_business             6
# singapore_pte                8
# state_art                   13

# %%
plt.figure(figsize=(20, 3))
litstudy.plot_word_distribution(corpus, limit=50, title="Top words", vertical=True, label_rotation=45);

# %%
num_topics = 50
topic_model = litstudy.train_nmf_model(corpus, num_topics, max_iter=250)

# %%
for i in range(num_topics):
    print(f'Topic {i+1}:', topic_model.best_tokens_for_topic(i))
# Out:
# Topic 1: ['vehicular', 'trust', 'edge', 'tasks', 'road']
# Topic 2: ['digital', 'entities', 'stream', 'tasks', 'objects']
# Topic 3: ['review', 'literature', 'systematic', 'study', 'approaches']
# Topic 4: ['healthcare', 'health', 'patients', 'review', 'medical']
# Topic 5: ['risks', 'global', 'expected', 'quality', 'arising']
# Topic 6: ['events', 'framework', 'adaptive', 'flexibility', 'security']
# Topic 7: ['health', 'innovative', 'enhance', 'product', 'storage']
# Topic 8: ['aggregation', 'collection', 'multi', 'agent', 'monitoring']
# Topic 9: ['cities', 'attacks', 'cause', 'smart', 'occurring']
# Topic 10: ['industrial', 'monitoring', 'electric', 'drawbacks', 'wireless']
# Topic 11: ['smart', 'cities', 'home', 'platform', 'service']
# Topic 12: ['encryption', 'scheme', 'transfer', 'privacy', 'security']
# Topic 13: ['traffic', 'allocation', 'filtering', 'mitigate', 'bandwidth']
# Topic 14: ['authentication', 'security', 'scheme', 'attacks', 'lightweight']
# Topic 15: ['strategies', 'study', 'decrease', 'suggested', 'like']
# Topic 16: ['blockchain', 'messages', 'collection', 'life', 'protection']
# Topic 17: ['big', 'analytics', 'mining', 'emerging', 'engineering']
# Topic 18: ['protocol', 'heterogeneous', 'code', 'crucial', 'low']
# Topic 19: ['hop', 'physical', 'throughput', 'determines', 'cyber']
# Topic 20: ['offloading', 'embedded', 'scheme', 'centric', 'vehicles']
# Topic 21: ['agent', 'transaction', 'intelligent', 'level', 'mobile']
# Topic 22: ['routing', 'clustering', 'objects', 'nodes', 'selection']
# Topic 23: ['identify', 'blockchain', 'transaction', 'centralized', 'integration']
# Topic 24: ['detection', 'personal', 'assisted', 'covid', 'anonymous']
# Topic 25: ['load_balancing', 'scheduling', 'balancing', 'load', 'tasks']
# Topic 26: ['containerization', 'technologies', 'integration', 'deployment', 'modern']
# Topic 27: ['stream', 'processing', 'scale', 'benchmark', 'platform']
# Topic 28: ['function', 'practices', 'bandwidth', 'context', 'case']
# Topic 29: ['agriculture', 'filtering', 'product', 'review', 'trends']
# Topic 30: ['aggregation', 'delay', 'serve', 'energy', 'effective']
# Topic 31: ['fault_tolerant', 'fault', 'tolerant', 'dependability', 'qos']
# Topic 32: ['decision', 'support', 'relevant', 'understanding', 'making']
# Topic 33: ['allocation', 'optimization', 'evolution', 'transaction', 'efficient']
# Topic 34: ['privacy', 'messages', 'architecture', 'concerns', 'practices']
# Topic 35: ['covid', 'learning', 'model', 'deep', 'weights']
# Topic 36: ['additionally', 'delivery', 'area', 'covers', 'operation']
# Topic 37: ['workflow', 'scheduling', 'variety', 'algorithm', 'execution']
# Topic 38: ['sustainable', 'opportunities', 'open', 'offers', 'directions']
# Topic 39: ['encryption', 'security', 'preserving', 'protection', 'utilization']
# Topic 40: ['edge', 'directions', 'cloudlet', 'mobile', 'access']
# Topic 41: ['reduction', 'ratio', 'cost', 'bandwidth', 'monitoring']
# Topic 42: ['service', 'users', 'social', 'resource', 'cost']
# Topic 43: ['sdn', 'framework', 'ecosystem', 'defined', 'software']
# Topic 44: ['placement', 'store', 'consume', 'close', 'proximity']
# Topic 45: ['software', 'architecture', 'defined_networking', 'defined', 'blockchain']
# Topic 46: ['features', 'content', 'model', 'combining', 'platform']
# Topic 47: ['server', 'local', 'pushed', 'recommendations', 'era']
# Topic 48: ['reference', 'architecture', 'standard', 'building', 'metrics']
# Topic 49: ['edge', 'compression', 'code', 'ground', 'survey']
# Topic 50: ['driven', 'quality', 'home', 'dimensions', 'mobile']

# %%
plt.figure(figsize=(15, 5))
litstudy.plot_topic_clouds(topic_model, ncols=5);
# Out:
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# ...
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# D:\Liststudy\jupyterListstudy\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)

# %%
plt.figure(figsize=(20, 20))
litstudy.plot_embedding(corpus, topic_model);
# Out:
# D:\Liststudy\jupyterListstudy\lib\site-packages\sklearn\manifold\_t_sne.py:841: FutureWarning: The parameter `square_distances` has not effect and will be removed in version 1.3.
#   warnings.warn(

# %%
topic_id = topic_model.best_topic_for_token('smart')

# %%
for doc_id in topic_model.best_documents_for_topic(topic_id, limit=10):
    print(docs[int(doc_id)].title)
# Out:
# Design of Smart Dashboard based on IoT Fog Computing for Smart Cities
# A New Layered Architecture for Future Big Data-Driven Smart Homes
# Fog computing for smart cities’ big data management and analytics: A review
# Research on a Communication Platform Coordinating Web Services and Smart Speakers on the Application Layer
# Performance analysis of the ubiquitous and emergent properties of an autonomic reflective middleware for smart cities
# Edge-Computing-Enabled Smart Cities: A Comprehensive Survey
# A Reference Architecture for IoT-Enabled Smart Buildings
# A verifiable privacy-preserving data collection scheme supporting multi-party computation in fog-based smart grid
# A Review On Relationship Between Iot- Cloud Computing - Fog Computing (Applications And Challenges)
# From cloud computing to fog computing: Two technologies to serve iot-a review-

# %%
threshold = 0.2
dl_topic = topic_model.doc2topic[:, topic_id] > threshold

docs = docs.add_property('dl_topic', dl_topic)


groups = {
    'edge': 'dl_topic',
    'other': 'not dl_topic', 
}

litstudy.plot_year_histogram(docs, groups=groups, stacked=True);

# %%
table = litstudy.compute_year_histogram(docs, groups=groups)
table.div(table.sum(axis=1), axis=0) * 100
# Out:
#            edge       other
# 2019  11.111111   88.888889
# 2020   8.823529   91.176471
# 2021  11.428571   88.571429
# 2022   4.347826   95.652174
# 2023   0.000000  100.000000

# %%
plt.figure(figsize=(10, 10))
litstudy.plot_source_histogram(docs, groups=groups, limit=25, stacked=True);

# %%
# Compute histogram by publication venue
table = litstudy.compute_source_histogram(docs, groups=groups)

# Add column 'total'
table['total'] = table['edge'] + table['other']

# Remove rare venues that have less than 5 publications
table = table[table['total'] >= 5]

# Add column 'ratio'
table['ratio'] = table['edge'] / table['total'] * 100

# Sort by ratio in descending order
table.sort_values(by='ratio', ascending=False)
# Out:
#                                  edge  other  total      ratio
# SN Computer Science                 2      8     10  20.000000
# IEEE Access                         1      4      5  20.000000
# IEEE Internet of Things Journal     1      6      7  14.285714
# Computing                           1     14     15   6.666667
# Journal of Supercomputing           0     24     24   0.000000
